# %% [markdown]
# # ***PROJECT NAME - AirBnb Bookings Analysis***

# %% [markdown]
# ![th (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Project Type -** EDA/AirBnb Booking Analysis
#
# **Contribution** - Individual
#
# **Name** - Neeraj Singh Bisht

# %% [markdown]
# # **Project Summary -**
# The analysis of the Airbnb dataset has revealed valuable insights into various aspects of the listings in New York City. The majority of listings are in the "Entire home/apt" and "Private room" categories, indicating a preference for privacy and independence. Manhattan and Brooklyn are the most popular neighbourhoods, with higher prices and longer minimum stay requirements compared to other areas. The analysis has also highlighted the importance of pricing and availability, with variations based on room types and neighbourhoods. Geographical analysis has identified specific regions with higher prices and longer minimum stay requirements, providing guidance for selecting suitable accommodations.
# Based on these insights, several solutions have been proposed to address business problems. These include refining pricing strategies, promoting underrepresented neighbourhoods, enhancing search filters and user interfaces, and improving guest experiences. The findings also emphasize the significance of data-driven decision making and collaborations with local authorities to optimize operations and comply with regulations. By leveraging these insights, Airbnb can enhance the user experience, attract more hosts and guests, and improve overall business performance in the competitive short-term rental market in New York City.

# %% [markdown]
# # [Github Link] (https://github.com/theshifuji/Airbnb-Exploratory-Data-Analysis)

# %% [markdown]
# # **Problem Statement**
# Performing Exploratory Data Analysis (EDA) on the AirBnb dataset poses several challenges due to its vast size, comprising millions of listings. Effective startegies are required to process and analyze this extensive dataset to extract valuable insights and pattern. The goal is to uncover trends, patterns and key features of the data to enhance decision-making and improve the eoverall AirBnb experience for host and user.

# %% [markdown]
# **Define Your Business Objective?**
#
# The objective of this project is to extract Valuable insight and patterns from the AirBnb dataset through dataset analysis techniques. By examining the factor such as trends, geographical distribution, popular amenities and more, we aim to gain a deeper understanding of various aspects related to AirBnb listings. The analysis will facilitate informed business decisions, enhance user experiences, and improve the overall performance of AirBnb as service.

# %% [markdown]
# # ***Let's Begin !***
#
# # ***1. Know Your Data***

# %% [markdown]
# **Import Libraries**

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import missingno as msno
import matplotlib.pyplot as plt
import folium
import warnings
import plotly.express as px
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ***Dataset Loading***

# %%
#loading dataset
BnB_Data = pd.read_csv('/content/drive/MyDrive/PROJECTS/EDA/Airbnb NYC 2019 (1).csv')

# %% [markdown]
# **Dataset First Look**

# %%
# Dataset First Look
BnB_Data.head(3).style.background_gradient(cmap='Oranges')
# Out:
# <style type="text/css">
# #T_6f765_row0_col0, #T_6f765_row0_col2, #T_6f765_row0_col6, #T_6f765_row0_col9, #T_6f765_row0_col10, #T_6f765_row0_col13, #T_6f765_row1_col7, #T_6f765_row1_col10, #T_6f765_row1_col15, #T_6f765_row2_col11, #T_6f765_row2_col14 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_6f765_row0_col7 {
#   background-color: #fdca99;
#   color: #000000;
# }
# #T_6f765_row0_col11, #T_6f765_row1_col14 {
#   background-color: #fdd9b4;
#   color: #000000;
# }
# #T_6f765_row0_col14, #T_6f765_row0_col15, #T_6f765_row1_col9, #T_6f765_row1_col11, #T_6f765_row1_col13, #T_6f765_row2_col0, #T_6f765_row2_col2, #T_6f765_row2_col6, #T_6f765_row2_col7, #T_6f765_row2_col10, #T_6f765_row2_col15 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_6f765_row1_col0 {
#   background-color: #ffefe0;
#   color: #000000;
# }
# #T_6f765_row1_col2 {
#   background-color: #fff1e4;
#   color: #000000;
# }
# #T_6f765_row1_col6 {
#   background-color: #eb600e;
#   color: #f1f1f1;
# }
# #T_6f765_row2_col9 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# #T_6f765_row2_col13 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6f765" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f765_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_6f765_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_6f765_level0_col2" class="col_heading level0 col2" >host_id</th>
#       <th id="T_6f765_level0_col3" class="col_heading level0 col3" >host_name</th>
#       <th id="T_6f765_level0_col4" class="col_heading level0 col4" >neighbourhood_group</th>
#       <th id="T_6f765_level0_col5" class="col_heading level0 col5" >neighbourhood</th>
#       <th id="T_6f765_level0_col6" class="col_heading level0 col6" >latitude</th>
#       <th id="T_6f765_level0_col7" class="col_heading level0 col7" >longitude</th>
#       <th id="T_6f765_level0_col8" class="col_heading level0 col8" >room_type</th>
#       <th id="T_6f765_level0_col9" class="col_heading level0 col9" >price</th>
#       <th id="T_6f765_level0_col10" class="col_heading level0 col10" >minimum_nights</th>
#       <th id="T_6f765_level0_col11" class="col_heading level0 col11" >number_of_reviews</th>
#       <th id="T_6f765_level0_col12" class="col_heading level0 col12" >last_review</th>
#       <th id="T_6f765_level0_col13" class="col_heading level0 col13" >reviews_per_month</th>
#       <th id="T_6f765_level0_col14" class="col_heading level0 col14" >calculated_host_listings_count</th>
#       <th id="T_6f765_level0_col15" class="col_heading level0 col15" >availability_365</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f765_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f765_row0_col0" class="data row0 col0" >2539</td>
#       <td id="T_6f765_row0_col1" class="data row0 col1" >Clean & quiet apt home by the park</td>
#       <td id="T_6f765_row0_col2" class="data row0 col2" >2787</td>
#       <td id="T_6f765_row0_col3" class="data row0 col3" >John</td>
#       <td id="T_6f765_row0_col4" class="data row0 col4" >Brooklyn</td>
#       <td id="T_6f765_row0_col5" class="data row0 col5" >Kensington</td>
#       <td id="T_6f765_row0_col6" class="data row0 col6" >40.647490</td>
#       <td id="T_6f765_row0_col7" class="data row0 col7" >-73.972370</td>
#       <td id="T_6f765_row0_col8" class="data row0 col8" >Private room</td>
#       <td id="T_6f765_row0_col9" class="data row0 col9" >149</td>
#       <td id="T_6f765_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_6f765_row0_col11" class="data row0 col11" >9</td>
#       <td id="T_6f765_row0_col12" class="data row0 col12" >2018-10-19</td>
#       <td id="T_6f765_row0_col13" class="data row0 col13" >0.210000</td>
#       <td id="T_6f765_row0_col14" class="data row0 col14" >6</td>
#       <td id="T_6f765_row0_col15" class="data row0 col15" >365</td>
#     </tr>
#     <tr>
#       <th id="T_6f765_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6f765_row1_col0" class="data row1 col0" >2595</td>
#       <td id="T_6f765_row1_col1" class="data row1 col1" >Skylit Midtown Castle</td>
#       <td id="T_6f765_row1_col2" class="data row1 col2" >2845</td>
#       <td id="T_6f765_row1_col3" class="data row1 col3" >Jennifer</td>
#       <td id="T_6f765_row1_col4" class="data row1 col4" >Manhattan</td>
#       <td id="T_6f765_row1_col5" class="data row1 col5" >Midtown</td>
#       <td id="T_6f765_row1_col6" class="data row1 col6" >40.753620</td>
#       <td id="T_6f765_row1_col7" class="data row1 col7" >-73.983770</td>
#       <td id="T_6f765_row1_col8" class="data row1 col8" >Entire home/apt</td>
#       <td id="T_6f765_row1_col9" class="data row1 col9" >225</td>
#       <td id="T_6f765_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_6f765_row1_col11" class="data row1 col11" >45</td>
#       <td id="T_6f765_row1_col12" class="data row1 col12" >2019-05-21</td>
#       <td id="T_6f765_row1_col13" class="data row1 col13" >0.380000</td>
#       <td id="T_6f765_row1_col14" class="data row1 col14" >2</td>
#       <td id="T_6f765_row1_col15" class="data row1 col15" >355</td>
#     </tr>
#     <tr>
#       <th id="T_6f765_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6f765_row2_col0" class="data row2 col0" >3647</td>
#       <td id="T_6f765_row2_col1" class="data row2 col1" >THE VILLAGE OF HARLEM....NEW YORK !</td>
#       <td id="T_6f765_row2_col2" class="data row2 col2" >4632</td>
#       <td id="T_6f765_row2_col3" class="data row2 col3" >Elisabeth</td>
#       <td id="T_6f765_row2_col4" class="data row2 col4" >Manhattan</td>
#       <td id="T_6f765_row2_col5" class="data row2 col5" >Harlem</td>
#       <td id="T_6f765_row2_col6" class="data row2 col6" >40.809020</td>
#       <td id="T_6f765_row2_col7" class="data row2 col7" >-73.941900</td>
#       <td id="T_6f765_row2_col8" class="data row2 col8" >Private room</td>
#       <td id="T_6f765_row2_col9" class="data row2 col9" >150</td>
#       <td id="T_6f765_row2_col10" class="data row2 col10" >3</td>
#       <td id="T_6f765_row2_col11" class="data row2 col11" >0</td>
#       <td id="T_6f765_row2_col12" class="data row2 col12" >nan</td>
#       <td id="T_6f765_row2_col13" class="data row2 col13" >nan</td>
#       <td id="T_6f765_row2_col14" class="data row2 col14" >1</td>
#       <td id="T_6f765_row2_col15" class="data row2 col15" >365</td>
#     </tr>
#   </tbody>
# </table>

# %%
#This is the tail of the the Airbnb dataset
BnB_Data.tail(2).style.background_gradient(cmap='Oranges')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/style.py:3931: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/style.py:3932: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_bc8d3_row0_col0, #T_bc8d3_row0_col2, #T_bc8d3_row0_col6, #T_bc8d3_row0_col7, #T_bc8d3_row0_col9, #T_bc8d3_row0_col10, #T_bc8d3_row0_col11, #T_bc8d3_row0_col15, #T_bc8d3_row1_col11, #T_bc8d3_row1_col14 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_bc8d3_row0_col13, #T_bc8d3_row1_col13 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_bc8d3_row0_col14, #T_bc8d3_row1_col0, #T_bc8d3_row1_col2, #T_bc8d3_row1_col6, #T_bc8d3_row1_col7, #T_bc8d3_row1_col9, #T_bc8d3_row1_col10, #T_bc8d3_row1_col15 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bc8d3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc8d3_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_bc8d3_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_bc8d3_level0_col2" class="col_heading level0 col2" >host_id</th>
#       <th id="T_bc8d3_level0_col3" class="col_heading level0 col3" >host_name</th>
#       <th id="T_bc8d3_level0_col4" class="col_heading level0 col4" >neighbourhood_group</th>
#       <th id="T_bc8d3_level0_col5" class="col_heading level0 col5" >neighbourhood</th>
#       <th id="T_bc8d3_level0_col6" class="col_heading level0 col6" >latitude</th>
#       <th id="T_bc8d3_level0_col7" class="col_heading level0 col7" >longitude</th>
#       <th id="T_bc8d3_level0_col8" class="col_heading level0 col8" >room_type</th>
#       <th id="T_bc8d3_level0_col9" class="col_heading level0 col9" >price</th>
#       <th id="T_bc8d3_level0_col10" class="col_heading level0 col10" >minimum_nights</th>
#       <th id="T_bc8d3_level0_col11" class="col_heading level0 col11" >number_of_reviews</th>
#       <th id="T_bc8d3_level0_col12" class="col_heading level0 col12" >last_review</th>
#       <th id="T_bc8d3_level0_col13" class="col_heading level0 col13" >reviews_per_month</th>
#       <th id="T_bc8d3_level0_col14" class="col_heading level0 col14" >calculated_host_listings_count</th>
#       <th id="T_bc8d3_level0_col15" class="col_heading level0 col15" >availability_365</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc8d3_level0_row0" class="row_heading level0 row0" >48893</th>
#       <td id="T_bc8d3_row0_col0" class="data row0 col0" >36485609</td>
#       <td id="T_bc8d3_row0_col1" class="data row0 col1" >43rd St. Time Square-cozy single bed</td>
#       <td id="T_bc8d3_row0_col2" class="data row0 col2" >30985759</td>
#       <td id="T_bc8d3_row0_col3" class="data row0 col3" >Taz</td>
#       <td id="T_bc8d3_row0_col4" class="data row0 col4" >Manhattan</td>
#       <td id="T_bc8d3_row0_col5" class="data row0 col5" >Hell's Kitchen</td>
#       <td id="T_bc8d3_row0_col6" class="data row0 col6" >40.757510</td>
#       <td id="T_bc8d3_row0_col7" class="data row0 col7" >-73.991120</td>
#       <td id="T_bc8d3_row0_col8" class="data row0 col8" >Shared room</td>
#       <td id="T_bc8d3_row0_col9" class="data row0 col9" >55</td>
#       <td id="T_bc8d3_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_bc8d3_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_bc8d3_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_bc8d3_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_bc8d3_row0_col14" class="data row0 col14" >6</td>
#       <td id="T_bc8d3_row0_col15" class="data row0 col15" >2</td>
#     </tr>
#     <tr>
#       <th id="T_bc8d3_level0_row1" class="row_heading level0 row1" >48894</th>
#       <td id="T_bc8d3_row1_col0" class="data row1 col0" >36487245</td>
#       <td id="T_bc8d3_row1_col1" class="data row1 col1" >Trendy duplex in the very heart of Hell's Kitchen</td>
#       <td id="T_bc8d3_row1_col2" class="data row1 col2" >68119814</td>
#       <td id="T_bc8d3_row1_col3" class="data row1 col3" >Christophe</td>
#       <td id="T_bc8d3_row1_col4" class="data row1 col4" >Manhattan</td>
#       <td id="T_bc8d3_row1_col5" class="data row1 col5" >Hell's Kitchen</td>
#       <td id="T_bc8d3_row1_col6" class="data row1 col6" >40.764040</td>
#       <td id="T_bc8d3_row1_col7" class="data row1 col7" >-73.989330</td>
#       <td id="T_bc8d3_row1_col8" class="data row1 col8" >Private room</td>
#       <td id="T_bc8d3_row1_col9" class="data row1 col9" >90</td>
#       <td id="T_bc8d3_row1_col10" class="data row1 col10" >7</td>
#       <td id="T_bc8d3_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_bc8d3_row1_col12" class="data row1 col12" >nan</td>
#       <td id="T_bc8d3_row1_col13" class="data row1 col13" >nan</td>
#       <td id="T_bc8d3_row1_col14" class="data row1 col14" >1</td>
#       <td id="T_bc8d3_row1_col15" class="data row1 col15" >23</td>
#     </tr>
#   </tbody>
# </table>
